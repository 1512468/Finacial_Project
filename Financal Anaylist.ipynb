# %% [markdown]
# ####  Fix max size

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', -1)
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# !pip install numpy

# %%
import pandas as pd 
import os 
import numpy as np

# %%
df = pd.read_excel("/home/suv/Desktop/Bizda301/data_samples/Financial Sample.xlsx");

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df.mean();

# %%
df
# Out:
#               Segment                   Country    Product Discount Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units Sold  Manufacturing Price  Sale Price  Gross Sales  Discounts  \
# ...

# %%
df1 = df[['COGS','Discounts']]

# %%
import seaborn as sns

# %%
data_visualations = sns.heatmap(df1)

# %%
df.head(10)
# Out:
#             Segment  Country    Product Discount Band  Units Sold  \
# 0        Government   Canada  Carretera          None      1618.5
# 1        Government  Germany  Carretera          None      1321.0
# 2         Midmarket   France  Carretera          None      2178.0
# 3         Midmarket  Germany  Carretera          None       888.0
# 4         Midmarket   Mexico  Carretera          None      2470.0
# 5        Government  Germany  Carretera          None      1513.0
# 6         Midmarket  Germany    Montana          None       921.0
# 7  Channel Partners   Canada    Montana          None      2518.0
# 8        Government   France    Montana          None      1899.0
# 9  Channel Partners  Germany    Montana          None      1545.0
#
#    Manufacturing Price  Sale Price  Gross Sales  Discounts     Sales  \
# 0                    3          20      32370.0        0.0   32370.0
# 1                    3          20      26420.0        0.0   26420.0
# ...

# %%
list(df1)
# Out:
# ['COGS', 'Discounts']

# %%
df1.dtypes
# Out:
# COGS         float64
# Discounts    float64
# dtype: object

# %%
import pandas as pd

# %%
df2 = pd.read_excel("/home/suv/Desktop/Bizda301/data_samples/Ultimate Beginners Guide to DAX data file.xlsx");

# %%
list(df2)
# Out:
# ['Order ID',
#  'Product ID',
#  'Location ID',
#  'Sales Person ID',
#  'Customer ID',
#  'Purchase Date',
#  'Quantity']

# %%
df2.head(10)
# Out:
#   Order ID Product ID Location ID Sales Person ID Customer ID Purchase Date  \
# 0  AX10001  ENX2071    A109        EMP1009         C1499      2015-09-23
# 1  AX10002  ENX2053    A109        EMP1007         C1359      2015-02-07
# 2  AX10003  ENX2058    A114        EMP1012         C1257      2017-04-15
# 3  AX10004  ENX2029    A132        EMP1019         C1078      2017-02-23
# 4  AX10005  ENX2030    A142        EMP1003         C1220      2015-06-27
# 5  AX10006  ENX2078    A108        EMP1034         C1125      2017-06-23
# 6  AX10007  ENX2001    A142        EMP1003         C1368      2015-01-12
# 7  AX10008  ENX2076    A186        EMP1015         C1121      2016-02-13
# 8  AX10009  ENX2082    A171        EMP1029         C1764      2015-07-28
# 9  AX10010  ENX2071    A147        EMP1019         C1681      2017-12-07
#
#    Quantity
# 0  1
# 1  1
# 2  2
# 3  4
# 4  1
# 5  1
# 6  4
# 7  2
# 8  1
# 9  2
